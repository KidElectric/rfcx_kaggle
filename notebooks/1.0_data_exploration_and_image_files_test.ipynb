# %%
import numpy as np
import pandas as pd
import librosa as lb
import librosa.display
import soundfile as sf
import matplotlib.patches as patch
import matplotlib.pyplot as plt
import IPython.display as ipd
from pathlib import Path
from tqdm.notebook import tqdm
from scipy.io import wavfile
import time
import os
import shutil
import sklearn.metrics as skm
from skimage import io
from skimage.color import rgb2gray,rgba2rgb

# %matplotlib inline

DATA_ROOT = Path("D:\\rfcx-species-audio-detection")
TRAIN_AUDIO_ROOT = Path("D:\\rfcx-species-audio-detection\\train")
TEST_AUDIO_ROOT = Path("D:\\rfcx-species-audio-detection\\test")

df_train = pd.DataFrame({
    "recording_id": [path.stem for path in Path(TRAIN_AUDIO_ROOT).glob("*.flac")],
})

df_test = pd.DataFrame({
    "recording_id": [path.stem for path in Path(TEST_AUDIO_ROOT).glob("*.flac")],
})

df_tp=pd.read_csv(DATA_ROOT.joinpath('train_tp.csv')).set_index('recording_id')

df_fp=pd.read_csv(DATA_ROOT.joinpath('train_fp.csv')).set_index('recording_id')

# %%
#average_precision_score 
# ?skm.label_ranking_average_precision_score

# %%
from fastai.vision.all import *

# %%
# ?cnn_learner

# %%
cuda.empty_cache()

# %%
class params:
    """
    Parameters used for generating spectrograms from audio data
    """
    sr = 48000 #sampling rate

    # Melspectrogram
    n_mels = 128
    fmin = 80
    fmax = 14000  
    n_fft=2048
    hop_length = 512
    
def load_audio(record, sr=48000, root=""):
    y, _ = lb.load(
        root.joinpath(record).with_suffix(".flac"),
        sr=sr, 
    )
    return y

def compute_melspec(y, params):
    """
    Computes a mel-spectrogram and puts it at decibel scale
    Arguments:
        y {np array} -- signal
        params {AudioParams} -- Parameters to use for the spectrogram. Expected to have the attributes sr, n_mels, f_min, f_max
    Returns:
        np array -- Mel-spectrogram
    """
    melspec = lb.feature.melspectrogram(
        y, sr=params.sr, n_mels=params.n_mels, fmin=params.fmin, fmax=params.fmax, hop_length=params.hop_length,n_fft=params.n_fft
    )
    melspec = lb.power_to_db(melspec).astype(np.float32)
    return melspec
def subtract_median(med,melspec):
    med_sub=np.zeros(melspec.shape)
    for i,col in enumerate(melspec.transpose()):
        med_sub[:,i]=col-med 
    return med_sub

def make_box(df_tp,recording):
    t_start=df_tp['t_min'][recording]
    t_stop= df_tp['t_max'][recording]
    f_min= df_tp['f_min'][recording]
    f_max= df_tp['f_max'][recording]
    #matplotlib.patches.Rectangle(xy, width, height, angle=0.0, **kwargs)
    width=t_stop-t_start
    height=f_max-f_min
    xy=(t_start,f_min)
    return t_start, t_stop, f_min, f_max

# %% [markdown]
# # EXAMPLE SPECTROGRAM

# %%
## TONE TEST:
import numpy as np

sampleRate = 48000
frequency = 500
length = 5

t = np.linspace(0, length, sampleRate * length)  #  Produces a 5 second Audio-File
y = np.sin(frequency * 2 * np.pi * t)  #  Has frequency of 440Hz

wavfile.write(DATA_ROOT.joinpath('sine_%dhz.wav' % frequency), sampleRate, y)

# %%
#Plot known spectrum: 5s 500Hz sine wave:
fn='sine_500hz.wav'
pnfn=DATA_ROOT.joinpath(fn)
_,fs=sf.read(pnfn)

params.sr=fs
params.fmax=5000
y, _ = lb.load(pnfn, sr=fs)
print('Duration: %ds, fs: %d' % (y.shape[0]/fs, fs))
params.hop_length=512
params.nmels=128
params.fmin = 20
params.fmax = 5000  
params.n_fft=2048
melspec = compute_melspec(y, params)

fig, ax = plt.subplots(figsize=(15, 5))
img = librosa.display.specshow(
    melspec, 
    sr=params.sr,
    x_axis='time', 
    y_axis='mel',
    hop_length=params.hop_length,
    fmax=params.fmax,
    ax=ax)
fig.colorbar(img, ax=ax, format="%+2.f dB")

fm=3100
fx=3300
x=[0,10]
yy=[fm, fm]
ax.plot(x,yy,'c')

x=[0,10]
yy=[fx,fx]
ax.plot(x,yy,'c')

plt.show()
# Out:
# Duration: 5s, fs: 48000
# C:\Users\Brian\anaconda3\envs\fastai2\lib\site-packages\librosa\display.py:974: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   scaler(mode, **kwargs)
# C:\Users\Brian\anaconda3\envs\fastai2\lib\site-packages\librosa\display.py:974: MatplotlibDeprecationWarning: The 'linthreshy' parameter of __init__() has been renamed 'linthresh' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   scaler(mode, **kwargs)

# %%
type(singer)
# Out:
# numpy.int64

# %%
fn=df_tp.index[157]

pnfn=TRAIN_AUDIO_ROOT.joinpath('0_raw').joinpath(fn).with_suffix(".flac")
_,fs=sf.read(pnfn)
singer=df_tp['species_id'][fn]
params.sr=fs

y = load_audio(fn, params.sr, TRAIN_AUDIO_ROOT.joinpath('0_raw'))
print(y.shape[0]/fs)
if isinstance(singer,np.int64):
    y=y[round(df_tp['t_min'][fn]*fs) : round(df_tp['t_max'][fn]*fs)]
else:
    y=y[round(df_tp['t_min'][fn][0]*fs) : round(df_tp['t_max'][fn][0]*fs)]
print((singer,fs,y.shape[0]/fs))
melspec = compute_melspec(y, params)
keep=melspec
med=np.median(melspec,axis=1)
melspec=subtract_median(med,melspec)
min_med=0
max_med=np.max(melspec)
mm=-1*med
mm[mm<0]=0
mm=mm-np.min(mm)
mm=mm/np.max(mm)
mm=mm*np.max(melspec)

melspec=np.column_stack((melspec,mm))
melspec[melspec < 0]=0
# melspec=np.log10(melspec)
# melspec[melspec < 0]=0
m=np.max(melspec)
print(m)
#Make bounding box of audio of interest:

fig, ax = plt.subplots(figsize=(15, 5))

img = librosa.display.specshow(
    melspec,
    sr=params.sr,
    x_axis='time', 
    y_axis='linear', 
    cmap='bwr',
    hop_length=params.hop_length,
    ax=ax)
fig.colorbar(img, ax=ax, format="%+2.f dB")

s,st,fm,fx = make_box(df_tp,fn)
ax.set_ylim((params.fmin,params.fmax))
x=[0,10]
yy=[fm, fm]
ax.plot(x,yy,'c')

x=[0,10]
yy=[fx,fx]
ax.plot(x,yy,'c')

#plt.show()

print(s,st,fm,fx)
# Out:
# 60.0
# (4, 48000, 1.856)
# 45.04594039916992
# 1.9093 3.7653 2343.75 4218.75

# %%
y = load_audio(fn, params.sr, TRAIN_AUDIO_ROOT.joinpath('0_raw'))
S_full, phase = lb.magphase(librosa.stft(y))

# Try librosa segmentation example:
S_filter = lb.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(lb.time_to_frames(2, sr=params.sr)))

# The output of the filter shouldn't be greater than the input
# if we assume signals are additive.  Taking the pointwise minimium
# with the input spectrum forces this.
S_filter = np.minimum(S_full, S_filter)

# %%
# We can also use a margin to reduce bleed between the vocals and instrumentation masks.
# Note: the margins need not be equal for foreground and background separation
margin_i, margin_v = 2, 10
power = 2

mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)

# Once we have the masks, simply multiply them with the input spectrum
# to separate the components

S_foreground = mask_v * S_full
S_background = mask_i * S_full

# sphinx_gallery_thumbnail_number = 2
sr=params.sr
idx = slice(*lb.time_to_frames([0, 5], sr=params.sr))
plt.figure(figsize=(12, 8))
plt.subplot(3, 1, 1)
librosa.display.specshow(librosa.amplitude_to_db(S_full[:, idx], ref=np.max),
                         y_axis='log', sr=sr)
plt.title('Full spectrum')
plt.colorbar()

plt.subplot(3, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S_background[:, idx], ref=np.max),
                         y_axis='log', sr=sr)
plt.title('Background')
plt.colorbar()
plt.subplot(3, 1, 3)
librosa.display.specshow(librosa.amplitude_to_db(S_foreground[:, idx], ref=np.max),
                         y_axis='log', x_axis='time', sr=sr)
plt.title('Foreground')
plt.colorbar()
plt.tight_layout()
plt.show()

# %%
plt.plot(med)
plt.plot(melspec[:,35],'r')

# %%
fn=df_tp.index[1]
pnfn=TRAIN_AUDIO_ROOT.joinpath(fn).with_suffix(".flac")
_,fs=sf.read(pnfn)
y = load_audio(fn, fs, TRAIN_AUDIO_ROOT)

fig, ax = plt.subplots(figsize=(15, 5))
librosa.display.waveplot(y, sr=fs)

s,st,fm,fx = make_box(df_tp,fn)
x=[s,s]
yy=[-0.15, 0.15]
plt.plot(x,yy,'--r')

x=[st,st]
plt.plot(x,yy,'--r')
ax.set_xlim([s,st])
# Out:
# (39.9615, 46.0452)

# %%
ipd.Audio(np.array(y),rate=fs) # load a local WAV file
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def has_tp_fp(rec,df_tp,df_fp):
    #Many recordings have both tp and fp data labeled.
    has_tp=False
    has_fp=False
    if rec in df_tp.index:
        has_tp = True
    if rec in df_fp.index:
        has_fp = True
    return has_tp, has_fp

def clip_info(rec,df):
    keep={'species_id':[],'t_min':[],'t_max':[]}
    for key in df.keys():
        if key in keep.keys():
            if isinstance(df[key][rec],pd.core.series.Series):
                keep[key]=[val for val in df[key][rec].values]
            else:
                keep[key].append(df[key][rec])
    return keep




def save_spectrum_image(y,params):
    fs=params.sr
    ax=params.ax
    use_root=params.use_root
    melspec = compute_melspec(y, params) #Calculate full spectrogram
    med=np.median(melspec,axis=1) #Take median of full spectrogram
    if params.clip_method == 6: #Particularly for TEST set --> make into smaller clips
        
        #Make a folder for each recording:
        dest=params.use_root.joinpath(params.fn)
        if dest.exists()==False:
            os.mkdir(dest)
            
        # Make 10 6s clips:
        for c,i in enumerate(range(0,60,6)):
            t_min=i
            t_max=i+6
            y_short=y[round(t_min*fs) : round(t_max*fs -1)]
            melspec=compute_melspec(y_short,params)
            params.melspec=subtract_median(med,melspec)
            img_fn='%s_%d.png' % (params.fn,c)
            params.img_pnfn=dest.joinpath(img_fn)
            plot_and_save(params)
    else:
        if params.mode == 'TRAIN':                      
            if params.clip==True: 
                t_min=params.t_min
                t_max=params.t_max
                y=y[round(t_min*fs) : round(t_max*fs)] #Clip suggested time range
                melspec = compute_melspec(y, params) 
                img_fn='%s_%d_%s.png' % (params.type,params.spec,params.fn)
            else:
                img_fn='%s_%d_%s_full.png' % (params.type,params.spec,params.fn)
        else:
            img_fn='%s.png' % (params.fn)
        params.melspec= subtract_median(med,melspec) #Now subtract full spec median from clip or full spec
        params.img_pnfn=params.use_root.joinpath(img_fn)
        plot_and_save(params)

def plot_and_save(params):
        melspec=params.melspec
        img = librosa.display.specshow(
            melspec, 
            sr=params.sr,
            x_axis='time', 
            y_axis='linear', 
            hop_length=params.hop_length,
            cmap='bwr',
            ax=ax)
        #ax.set_ylim((params.fmin,params.fmin))
        ax.axis('off') 
        img_pnfn=params.img_pnfn
        print('\tSaving to %s' % img_pnfn)
        plt.savefig(img_pnfn)
        plt.cla()

# %%
# Make spectrum for each species in recording in train/test:
fig, ax = plt.subplots(figsize=(15, 5))
params.ax=ax
modes = ['TEST']
params.clip_method=6
for mode in modes:
    if mode == 'TEST':
        use_df=df_test
        use_root=TEST_AUDIO_ROOT
        params.clip=False 
    else:
        use_df=df_train
        use_root=TRAIN_AUDIO_ROOT
        params.clip=False #True = clip to identified length, False = use full
    params.use_root=use_root
    for ii,fn in enumerate(use_df['recording_id']):
        pnfn=use_root.joinpath(fn).with_suffix(".flac")
        _,fs=sf.read(pnfn)
        params.sr=fs
        params.mode=mode

        print('\n%d of %d' % (ii, len(use_df['recording_id'])))
        print('\tLoading %s' % pnfn)
        y = load_audio(fn, params.sr, use_root)

        print('\t Melspec...')
        params.fn=fn
        if mode == 'TRAIN':
            has_tp, has_fp = has_tp_fp(fn,df_tp,df_fp)
            if has_tp:
                info= clip_info(fn,df_tp)
                for i,spec in enumerate(info['species_id']):
                    params.type='TP'
                    params.spec=spec
                    params.t_min=info['t_min'][i]
                    params.t_max=info['t_max'][i]
                    save_spectrum_image(y,params)

            if has_fp:
                info= clip_info(fn,df_fp)
                for i,spec in enumerate(info['species_id']):
                    params.type='FP'
                    params.spec=spec
                    params.t_min=info['t_min'][i]
                    params.t_max=info['t_max'][i]
                    save_spectrum_image(y,params)

        else:
            save_spectrum_image(y,params)
# Out:
# 0 of 1992
# 	Loading D:\rfcx-species-audio-detection\test\000316da7.flac
# 	 Melspec...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-54abd8643721> in <module>
#      47
#      48         else:
# ---> 49             save_spectrum_image(y,params)
#      50
#      51
#
# NameError: name 'save_spectrum_image' is not defined

# %%
# %debug
# Out:
# > c:\users\brian\anaconda3\envs\fastai2\lib\site-packages\numpy\lib\arraypad.py(819)pad()
#     817                 raise ValueError(
#     818                     "can't extend empty axis {} using modes other than "
# --> 819                     "'constant' or 'empty'".format(axis)
#     820                 )
#     821         # passed, don't need to do anything more as _pad_simple already
#
# ipdb> quit

# %%
# If full TP has only one species, copy that into TP also.
use_df=df_train
use_root=TRAIN_AUDIO_ROOT
for ii,fn in enumerate(use_df['recording_id']):
    has_tp, has_fp = has_tp_fp(fn,df_tp,df_fp)
    if has_tp:
        info= clip_info(fn,df_tp)
        if len(info['species_id']) == 1:
            img_fn='%s_%d_%s_full.png' % ('TP',info['species_id'][0],fn)
            shutil.copy(use_root.joinpath(img_fn), use_root.joinpath('tp_clips'))
            print('from %s to %s' % (use_root.joinpath(img_fn), use_root.joinpath('tp_clips')))
# Out:
# from D:\rfcx-species-audio-detection\train\TP_14_003bec244_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_23_006ab765f_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_12_007f87ba2_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_17_0099c367b_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_10_009b760e6_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_8_00b404881_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_0_00d442df7_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_18_011f25080_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_15_015113cad_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_1_0151b7d20_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_6_01b41f92b_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_10_0201197ec_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_7_0209f7ab2_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_0_0268057eb_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_11_0275e127d_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_11_0295e3234_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_13_0297d886e_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_12_02b9a8ab9_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_16_0313e82cf_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_0_03d77fede_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_18_043356ff8_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_19_04975ecd8_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_17_04d6b1fc1_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_7_04e70a8e3_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_6_0509303a5_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_3_050d0ca85_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_14_055088446_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_10_055d22517_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_11_057802c25_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_2_05b9c974c_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_4_05f8c0f2f_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_0_067f49f8b_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_12_068f1b8e2_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_0_06a0c48c9_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_3_06c44d203_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_12_073e4d908_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_15_078788674_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_8_07d1687e0_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_10_07dcf40f7_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_1_07f1227b0_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_16_08db743d0_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_7_090ae427d_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_22_09315d9bf_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_12_0968aea09_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_23_09a946316_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_19_0a350d11c_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_7_0a9cdd8a5_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_9_0ab6aa734_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_12_0b2fa3f80_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_6_0b3ef9c4e_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_21_0c2124550_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_17_0c448e77c_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_17_0c48ed342_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_17_0c936a1d4_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_13_0cb4632d6_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_1_0d25045a9_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_2_0e034f968_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_15_0e29d05ed_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_2_0e2e4ac19_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_18_0e799da44_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_0_0ea8ea68a_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_3_0eb2079ea_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_13_0f8cadb4a_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_11_0f99800b7_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_18_0fc62dd3c_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_2_100e4ddc9_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_20_103db6411_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_18_10dae79ed_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_15_119b154cc_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_18_11a52d37a_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_23_11bafff5d_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_17_1263c23c8_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_8_12a12f0fa_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_9_12ec1d4cb_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_3_133001416_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_1_13511f7bd_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_21_1375a05d1_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_10_1383208d3_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_1_13c678c1d_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_11_13de5cabb_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_1_13f64f898_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_14_1414bbe17_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_1_141675c80_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_7_147b41b13_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_13_14948ff80_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_8_14d467153_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_13_14dc5a39e_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_3_14f6cbe5c_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_18_1504619b7_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_13_1520a52ef_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_9_1535d0c9b_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_19_1545e29b3_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_1_156b77dfe_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_0_157a50231_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_16_158c5acb6_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_18_15d9e6d8b_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_2_160b70831_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_3_163e86660_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_14_1679e323d_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_14_16ccddf71_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_1_16fc37168_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_14_16ffcf223_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_22_1702d35a0_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_5_1795728ba_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_4_17ca62c97_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_16_17ca96791_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_6
_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_5_e574b09d3_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_5_e585e1acb_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_1_e5d1f4efc_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_21_e65e42310_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_4_e6622a3c9_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_9_e666beee8_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_12_e6af91bbf_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_19_e71d72805_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_20_e734a1cde_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_1_e755e15ec_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_4_e7847849b_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_18_e7a81dc55_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_3_e7bc335fa_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_5_e7de0a728_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_22_e7dfc5c5f_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_23_e80890ff7_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_14_e8b209030_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_22_e9255d07c_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_16_e9622376a_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_14_e97de3f6d_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_15_e9bab320a_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_18_e9eb6d4dd_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_0_e9fa364b7_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_19_ea133d03e_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_12_ea71a1a7d_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_8_ea7aa9e69_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_7_ea7da0899_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_13_ea961733c_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_1_eac4c4220_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_8_eaf5cf482_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_6_eb0cd97da_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_5_eb3145e54_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_8_ebdd7c181_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_4_ec1255787_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_10_ec1c4a754_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_18_ec24a4d07_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_14_ec3a54dc6_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_5_ec63de3ab_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_23_ecd47f7cc_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_23_ed10a157a_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_18_ed2ae7025_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_4_ed36faac8_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_2_ed38c48b8_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_14_edd3b27d6_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_6_edf598655_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_23_ee3eab224_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_3_ee80e2415_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_13_eeb9a3c4b_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_11_eee00469a_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_8_ef10f60bf_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_12_ef3647390_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_11_efb6a2e01_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_14_efbfe6b39_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_8_f152e26e3_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_22_f1aa1c855_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_12_f1cc7d0a4_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_8_f2493eda1_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_11_f2890653e_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_4_f2c52223a_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_4_f2d7b8ed8_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_16_f33a1793f_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_21_f3b84afb1_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_23_f3cb40395_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_5_f4d05c0de_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_7_f51c0da28_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_11_f543f0d31_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_8_f55ce9e53_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_16_f5889157c_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_10_f5c3420f6_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_0_f5e6456f0_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_7_f6e41b038_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_14_f702f163c_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_9_f7466aeeb_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_10_f7d3b0080_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_23_f7d92975f_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_23_f84b8c8d3_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_9_f851b9605_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_5_f87ef432d_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_16_f8c661973_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_22_f9e724b46_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_8_fa0eee1e4_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_23_fa9353c0a_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_21_fb02b0607_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_14_fb3725395_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_23_fb5371e7b_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_21_fba69b00a_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_11_fbb31daeb_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_23_fbd5bbb6e_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_0_fc47cfba3_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_0_fc6609050_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_21_fc6c3b488_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_2_fd1970634_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_6_fd3f0d49b_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_8_fd6a520d8_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_5_fd7cc65e1_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_12_fdda158ed_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_20_fe8ce67c3_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_13_fe8d9ac40_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_4_fea6b438a_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_0_ff2eb9ce5_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_5_ffb8d8391_full.png to D:\rfcx-species-audio-detection\train\tp_clips
# from D:\rfcx-species-audio-detection\train\TP_18_ffb9a7b9a_full.png to D:\rfcx-species-audio-detection\train\tp_clips

# %%
# Combined many FP clips and 1 TP clip into new long clips:

#Generate MANY new long clips--for each TP, select 9 random FP and randomly concatenate together (approximating 60s clip)
dest=TRAIN_AUDIO_ROOT.joinpath('gen_full_tpfp')
if dest.exists()==False:
    os.mkdir(dest)
    #D:\rfcx-species-audio-detection\train\fp_clips\FP_8_00204008d.png
fp=[png for png in TRAIN_AUDIO_ROOT.joinpath('fp_clips').glob('*.png')]
for i,p in enumerate(fp[0:9]):
    im=rgb2gray(io.imread(p)[:,:,0:3])
    if i==0:
        a=im
    else:
        a=np.concatenate((a,im),axis=1)
    
fig, ax = plt.subplots(figsize=(15, 7))
plt.imshow(a,cmap='bwr')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.savefig(DATA_ROOT.joinpath('long_test.png'),dpi=250,pad_inches=0,bbox_inches='tight', transparent=True)
